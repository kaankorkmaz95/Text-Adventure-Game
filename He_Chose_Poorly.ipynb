# %%
"""
HE CHOSE POORLY: The Text Based Story Game
    
Created on 10/19/2020

@author: Kaan Korkmaz

    DocString:
    
    A) Introduction:
    This is the story of gambling addict who is struggling to make choices.
    Games are based on luck and a bit of knowledge on blackjack. 
    It is hard to win but again, it's hard to win all. 
    
    It has 3 games 
    - Die Roll (guessing the roll of a die)
    - Heads or Tails 
    - Blackjack 
    
    and defined functions for
    - Game start 
    - 4 different failing (himself, parents, all, main) 
    - A new card for card game
    - Float type checker
    - Winning
    - Exit
    
    B) Known Bugs and/or Errors:
    None.
    
    Note: Correct choices are always the 3rd ones
    
"""


# Importing necessary modules 
from sys import exit
from random import randint
import time

# Game starting function, start screen of the game 
def game_start(): 
  
    # Importing variables as global 
    global user_name
    global user_age
    global man_name
    
    # Starting the story, with sleep fnc in between. 
    print("""
In today's episode of 
*********************************
     'A Life Full of Choices'
*********************************
""")
    time.sleep(1)
    print("We are going to take a look at a man who will MAKE or BREAK.")
    print("You will be the one to make his choices for him.")
    print("At the end you will either rescue him, or kill his family.")
    
    # Getting the user's name name and capitilizing the first letter
    user_name = input(prompt = ("\nGive us your name \n>- ")).capitalize()
    
    # Welcoming the user
    print(f"Welcome {user_name}")
    print("To play this game you have to be 18+")
   
    #Age float checking loop
    i = 1 
    while i == 1:
        # Getting the user's age, and checking it
        a = input(prompt = ("\nHow old are you?\n>- "))
        if check_float(a) == 1:
            user_age = float(a)
            i = 0
        else:
            print("\nEnter a number.")
                    
    # Checking +18
    if user_age < 18:    
        print("\nYou are too young to do this.\n")        
        time.sleep(1)    
        print("Go get someone older than 18") 
        print("\nor just write your age older than 18") 
        print("we dont really care...")
        
        #Age float checking loop for second time
        i = 1 
        while i == 1:
            # Getting the user's age, and checking it
            a = input(prompt = ("\nHow old are you now? \n>- "))
            if check_float(a) == 1:
                user_age = float(a)
                i = 0
            else:
                print("\nEnter a number.")
         
        # Exit because of age
        if user_age < 18:
            print("Well ,okay then you can't play")
            ext()
        # Continuing    
        else:
            print ("\nGood, lets begin the story then...")
                
    print("To keep things secret, you will give this man a name.")
    
    # Getting character name and capitilizing the first letter 
    man_name = input(prompt = ("\nWhat is his name?\n>- ")).capitalize()
    
    # Starting the story of the man 
    print(f"""    
This is the story of {man_name}. 
He is a man with gambling addiction.
He lost all of his money. 

His mother borrowed some money from her friend 
to pay their home's morgage. """)
    
    # Putting enter to continue sections to make it easier to eat
    input("-------------------------\nPress enter to continue")  
    
    print(f""" 
His parents are old, and can't go to bank to pay it.
So, they had to give him the money and ask him to pay it. 

What they didn't know is that he took money from 
dangerous people and if he didn't pay today...""")
    
    # Waits for 3 seconds
    time.sleep(3)          
    print ("\nThey will KILL HIM")
    
    # Putting enter to continue sections to make it easier to eat
    input("-------------------------\nPress enter to continue\n") 
    
    # Asking for a decision
    print(f""" 
    He didn't know what to do. 

    Should 
    1)he pay the morgage and save his parents from being homeless?
    2)he pay the mafia and save his life?
    OR 
    3)he gamble the money and potentially pay everything?""")
    
    # Selection loop for the question
    i = 1 
    while i == 1:        
        # Getting the selection and making in lower case to better compare
        sel = input(prompt = ("\nWhat should he do? (1, 2 or 3)\n>- ")).lower() 
        #comparing the answers (only selection 3 continues)
        if "1" in sel or "one" in sel or "morgage" in sel or "family" in sel:
            i = 0
            dead()
        elif "2" in sel or "two" in sel or "mafia" in sel or "hi" in sel:
            i = 0
            fail_parents() 
        elif "3" in sel or "three" in sel or "gamble" in sel:
            i = 0 
            print(f"""
            
ALL IN...

You will save everyone, or ruin everyones life and end {man_name}'s""")               
        
        else:
            print("\nWe didn't quite get that.")
            
    # Continuing        
    print(f"So to gamble, {man_name} goes to his regular place.")
   
    time.sleep(1)     
    print(f"""        
He walks through a Chinese Restaurant to its kitchen, 
he goes through the kitchen to a back door to secret room. 
This is where he will be gambling.""")
    
    time.sleep(1)              
    print("\nThen suddenly he gets hit and falls.")
    
    # To make it easier to read
    input("-------------------------\nPress enter to continue\n") 
    time.sleep(1)
    print("""\n            
On the floor, he turns and sees the mafia. 
They found him and they were asking for their money.""")   
    
    # Asking question
    print(f"""\n 
    He didn't know what to do. 

    Should  
    1)he try to escape?
    2)he pay the mafia and save his life?
    OR 
    3)try to talk to them and explain himself?""")
    
    # Selection loop
    i = 1 
    while i == 1:
        # Getting the input and making it lower case
        sel = input(prompt = ("\nWhat should he do? (1, 2 or 3)\n>- ")).lower()
        #comparing the answers (only selection 3 continues)
        if "1" in sel or "one" in sel or "escape" in sel:
            i = 0
            dead()
        elif "2" in sel or "two" in sel or "mafia" in sel or "pay" in sel:
            i = 0
            fail_parents()     
        elif "3" in sel or "three" in sel or "talk" in sel or "explain" in sel:
            i = 0 
            print(f"\nHe gets up, beaten up tries to talk to them.")        
        else:
            print("\nWe didn't quite get that.")
    
    # Continues 
    print(f""" 
He just breaks down and tells them:

{man_name}:    
        I know I have to pay you with this money, but if I do,
        my parents will be homeless, they can't even walk I dont know 
        what to do.

{man_name}:     
        I CANNOT give you this money.
        PLEASE give me a chance or more time to pay you.""")
    
    # To make it easier to read
    input("-------------------------\nPress enter to continue\n")
    
    # Continuing
    print(f""" 
The mafia boss understands his situation, but also knows him.
If he gives {man_name} more time, he will not pay. 

He needs to put an end to this.""")
    
    time.sleep(3)
    print(f""" 
The Boss:
    "Okay, I'll give you a chance, but god knows you don't deserve it."
    "You will play every game here and you have to win."
    "If you can, I'll give your money back and erase your debt."
            
            
    You will play 

        Die Roll,

        Heads or Tails and 

        Blackjack""")
    
    time.sleep(1)
    print("""\n
You will play each of them 3 times.

If you win 
    1 out of 3 Die Roll games
    2 out of 3 Heads or Tails games
    3 our of 3 Blackjack games
    
    Then, you are free to go with your money. 

    You will start with die roll, then heads or tails, and blackjack at last.""")
    
    # To make it easier to read
    input("-------------------------\nPress enter to continue\n")
    
    time.sleep(1)
    print("""\n
The Boss:
    You wanted to play with your parents money, didn't you.
    Well, here you go. 

    GAMBLE""")
    
    # Asking the question
    print(f"""\n            
    Should 
    1)he try to escape with the money?
    2)decline the offer and pay the mafia?
    OR 
    3)Gamble?""")
    
    # Selection loop
    i = 1 
    while i == 1:
        sel = input(prompt = ("\nWhat should he do? (1, 2 or 3)\n>- ")).lower()
        #comparing the answers (only selection 3 continues)
        if "1" in sel or "one" in sel or "escape" in sel:
            i = 0
            dead()
        elif "2" in sel or "two" in sel or "mafia" in sel or "decline" in sel:
            i = 0
            fail_parents()
        elif "3" in sel or "three" in sel or "gamble" in sel:
            i = 0 
            print(f"""\n
----------------           
  LETS GAMBLE! 
----------------""")    
        else:
            print("\nWe didn't quite get that.")
      
    # To make it easier to read
    input("-------------------------\nPress enter to continue\n")
    
    # Continuing
    print(f"""           
He got up from the floor.
He walked to the die roll table.
He just needed to win one game put there was 1/6 chance of winning.""") 
    
    # Goes into Die Roll Game function
    die_roll()
    
    
#Die Roll Game function   
def die_roll():
    
    print(f"""\n 
{man_name} sat on the table with 3 other people            
They looked at him, smirky, smiling under their mustache    

{man_name}:
    'This better work'""")
    
    # To make it easier to read
    input("-------------------------\nPress enter to continue\n")
    
          #Continuing
    print(f"""
The cashier looked at him. 
"Good luck gentlemen" he said.             
and asked {man_name} for his choice.""")

    # Asking question loop
    count = 0
    win_count = 0
    for x in range(3):
        # Getting the input and making it lower case
        x = 1
        while x == 1:
            #comparing the answers (only selection 3 continues)
            a = input(prompt = ("\nWhat is your roll? (1-6)\n>- ")).lower()
            sides = a
            if "1" in sides or "one" in sides:
                x = 0 
                side = 1       
            elif "2" in sides or "two" in sides:
                x = 0
                side = 2
            elif "3" in sides or "three" in sides:
                x = 0
                side = 3
            elif "4" in sides or "four" in sides:
                x = 0
                side = 4
            elif "5" in sides or "five" in sides:
                x = 0
                side = 5
            elif "6" in sides or "six" in sides:
                x = 0
                side = 6    
            else:
                print(f"""\n
Cashier: What did you said? 
Say it again.
Chose 
   1, 2, 3, 4, 5 or 6""")

        # Randomly selecting the winner roll our of 6 
        win_num = randint(1,6)

        # If selection is the same as winning roll, user wins
        if win_num == side: 
            #increasing the winning and count
            win_count += 1
            count += 1
            # Winning one game is enough     
            if  win_count >= 1:
                time.sleep(1)
                print("\nYou WIN this round")
                print(f"""
    You WIN this round
    {man_name} won {win_count}/{count} rounds.
    ---------------
    CONGRATULATIONS 
    ---------------
    You passed this game. 
    Next game is Heads or Tails.\n""")           
                heads_tails()
                
            else: 
                time.sleep(1)
                print(f"\nIt was {win_num}\n")
                print("\nYou WIN this round")
                print("Congratulations, you are doing good.")
                print(f"\n{man_name} won {win_count}/{count} rounds.")
        # Losing the round    
        elif win_num != side:
            count += 1
            time.sleep(1)
            print(f"\nIt was {win_num}")
            print("\nYou LOST this round\n")  
            print(f"\n{man_name} won {win_count}/{count} rounds.")
    
    # If he didnt win any rounds
    if win_count == 0:
        print(f"\n{man_name} did not win any rounds.")
        #failing both himself and his family
        fail_all()
     
    # If he didnt win enough    
    elif win_count != 0:
        print(f"{man_name} won {win_count}/{count} rounds.\nand it was not enough.")
        #failing both himself and his family
        fail_all()

# Heads or Tails Game   
def heads_tails():
    
    # To make it easier to read
    input("-------------------------\nPress enter to continue\n")
    # Continuing
    print(f"\n{man_name} had passed the first round and felt the hope.")
    print("\nHe promised himself that if he gets out of this, he would never gamble again")
    time.sleep(1)
    print("""
He got up from Die Roll table and walked to the Heads and Tails table.             
The mafia was watching him all the time.             
When he get to the table the cashier, looked up, smiled and said; 
"Welcome back, long time no see"
""")
    
    time.sleep(2)
    print(f"""\n
{man_name} could not say anything.            
He knew the consequences.             
He sit in the chair and remain silent.""")
    
    # To make it easier to read
    input("-------------------------\nPress enter to continue\n")
    
    print(f"""\n
The cashier was still looking at him.             
He looked away  and said "Shame..."             
and asked {man_name} for his choice.""")
     
    # Asking question loop      
    count = 0
    win_count = 0
    for x in range(3):
        # Getting the input from the user and figuring out if its heads or tails
        x = 1
        while x == 1:
            # Getting the input and making it lower case to better compare
            side = input(prompt = ("""\n           
    1) Heads or 
    2) Tails?\n>-  """)).lower()
          
            #comparing the answers (only selection 3 continues)
            if "1" in side or "one" in side or "heads" in side:
                x = 0 
                coin = 1
            elif "2" in side or "two" in side or "tails" in side:
                x = 0
                coin = 2

            # Input not understood
            else:
                print("\nTalk louder son, I didn't understand that.")

        # Randomly selecting the winner out of 2  
        win_num = randint(1,2)

        # If selection is the same as winning roll, user wins, win counts increase
        if win_num == coin: 
            win_count += 1 
            count += 1
            time.sleep(1)
            print("\nYou WIN this round")
            print("\nCongratulations, you are doing good.")
            print(f"\n{man_name} won {win_count}/{count} rounds.")
            
            # Winning the required amount
            if  win_count >= 2:
                time.sleep(1)
                print("\nYou WIN this round")
                print("""\n
    ---------------
    CONGRATULATIONS 
    ---------------
    You passed this game. 
    Next Game is Blackjack. 
    Good luck there. 
                    
                """)           
                blackjack()
        # If round is lost   
        elif win_num != coin: 
            count += 1
            time.sleep(1)
            print("\nYou LOST this round")            
            print(f"\n{man_name} won {win_count}/{count} rounds.")
        
            # If didn't win any rounds
            if count == 2 and win_count == 0:
                print(f"\n{man_name} did not win any rounds.")
                fail_all()

            # If won rounds were not enough
            elif count == 3 and win_count != 0:
                print(f"{man_name} won {win_count}/{count} rounds\nbut it was not enough.")            
                fail_all()
      
            
# Blackjack game            
def blackjack():
    
    # To make it easier to read
    input("-------------------------\nPress enter to continue\n")
    # Continuing
    print(f"\n{man_name} had passed the second round too.")
    print(f"\nHe was feeling a bit relaxed. He sighed and rest his head back.")
    
    time.sleep(1)
    print(f"""\n
Just when he did that, he saw the mafia men standing behind him. 
He stopped smiling and got up. 

The Boss:
    "You need to win all of these rounds to save yourself"
    "And your family, don't get relaxed."
    """)
    
    # To make it easier to read
    input("-------------------------\nPress enter to continue\n")
    print(f"""\n
{man_name} was really scared now.
He was close yet so far.""")    
    time.sleep(2)
    print("""\n
He slowly walked to the last table: THe Blackjack table. 
The table was full. 
He stood there waiting someone to get up.""")         
    print(f"""\n    
The big guy stood up.             
Stood right next to him looking down to him.             
It was anger in his face.             
"Faster you lose faster you will leave here" he said.             
Spit on the floor, looked to {man_name}, and left the table.""")
    
    # To make it easier to read
    input("-------------------------\nPress enter to continue\n")
    print(f"""
{man_name} was embaressed. He knew he was not welcomed 
but now they hated him. 
He thought to himself:""")          
    print("I should have never come here.")
    time.sleep(2)
    print("I should have just paid the morgage.")
    time.sleep(2)
    print("I should have just die.")
               
    # To make it easier to read
    input("-------------------------\nPress enter to continue\n")
    print("""\n
He sat on the table. 
He couldn't even look at the cashier or other players.""")         
    time.sleep(2)
    print(f"""\n
The cashier did not say anything.             
He just started handing out the cards.""")
    
    # Starting the game loop
    count = 0
    win_count = 0
    for x in range(3):        
        # Pressing enter to get two cards
        input(prompt = ("<Press enter to get your 2 cards>\n"))

        # Using new_card() function to get two new cards from the deck, 
        # getting the value and the of the card
        first_card_user_val, first_card_user_name = new_card()
        second_card_user_val, second_card_user_name = new_card()

        # Calculating the value in user's hand
        hand_user = first_card_user_val + second_card_user_val

        # Using new_card() function to get two new cards from the deck, 
        # getting the value and the of the card
        first_card_table_val, first_card_table_name = new_card()
        second_card_table_val, second_card_table_name = new_card()

        # Calculating the value in user's hand
        hand_table = first_card_table_val + second_card_table_val

        # Printing the names, values of the cards for the user and the table 
        print(f"""\n
    You got {first_card_user_name} and {second_card_user_name}
    Your hand is {hand_user}.

    Table got {first_card_table_name} and {second_card_table_name}
    Table is {hand_table}.""") 

        # Pick a card loop, as long as user wants a new card and they are not burnt
        x = 1 
        burnt = False
        t_burnt = False
        while x == 1 and burnt != True:

            # Asking the user if they want a card and moking it lower case 
            select = input(prompt = (f"""\n
    To get another card enter
        1)Yes

    To stop enter
        2)Stop\n>- """)).lower() 

            # If they want a new card, after this it will ask again
            if "1" in select or "yes" in select or "one" in select:
                # Getting the value and the name of the card
                val,nam = new_card()
                # Increasing the user hand with the new card
                hand_user += val
                # Priting the results
                print(f"""\n
    You got {nam} with value {val}
    Your hand is {hand_user}.""") 

                # If after new card value is more than 21, user burnt, they lose
                if hand_user > 21:
                    burnt = True
                    print(f"\nYou got BURNT") 
          
                # If they have 21, they cant get more cards, they have the max
                elif hand_user == 21:
                    x = 0
                    print("""
    ---------------
       BLACKJACK
    ---------------""") 
          
            # If they dont want a new card, exits loop
            elif "2" in select or "stop" in select or "two" in select:
                x = 0
                print(f"""\n
    You stopped.
    Your hand is {hand_user}.""") 

            # If input is not understood, asks again.
            else:
                 print(f"""\n
    Sorry {user_name}, I didnt quite get that.
    Please chose again.""")

        # If user not burnt, it's table's turn
        if burnt != True:
            print(f"""\n
    Table's hand is {hand_table}
    It's table's turn""")     

            # Table will get a new card if hand value is less than 17
            while hand_table < 17:
                # Gets the values of the new card
                val, nam = new_card()
                # Increases the table hand value
                hand_table += val
                # Takes one secinf for every new card
                time.sleep(1)
                # Prints the result after each card    
                print(f"""\n
    Table got {nam} with value {val}
    Table's hand is {hand_table}.""") 
                # If table got burnt
                if hand_table > 21:
                    print("\nTable got BURNT")
                    t_burnt = True               
                    
            # After table stops, it shows the result
            print(f"""\n
    Table hand is {hand_table}
    Your hand is {hand_user}.""") 

            # If user have more, user wins
            if hand_user > hand_table or t_burnt == True:
                # Increasing winning count
                win_count += 1
                count += 1
                # Wins but not finishes
                if win_count != 3:
                    print("\nYou WIN this round")
                    print("\nCongratulations, you are doing good.")
                    print(f"\n{man_name} won {win_count}/{count} rounds.")
                # Wins every round
                if win_count == 3:               
                    time.sleep(1)
                    print("\nCONGRATULATIONS")
                    print("\nYou WON every round") 
                    win()

            # If user have less, table wins, loses all
            elif hand_user < hand_table:
                count += 1
                print("\nYou LOST this round")
                print("\nYou should have won every game in blackjack")  
                fail_all()
                
            # If equal    
            elif hand_user == hand_table: 
                count += 1
                b = 1
                while b == 1:
                    print("\nYou have the same card as table.")
                    print("\nBoth will pick a card and the highest will win this round.")

                    #Getting user input
                    input(prompt = ("\n<Press enter to get your card>\n>- "))

                    # Using new_card() function to get two new cards from the deck, 
                    # getting the value and the of the card
                    u_card_val, u_card_name = new_card()
                    t_card_val, t_card_name = new_card()

                    # Printing Results 
                    print(f"\nYour card: {u_card_name} ({u_card_val})")
                    print(f"\nTable's card: {t_card_name} ({t_card_val})")

                    if u_card_val > t_card_val:
                        win_count += 1
                        b = 0 
                        time.sleep(1)
                        print("\nYou WIN this round")
                        print("\nCongratulations, you are doing good.")
                        print(f"\n{man_name} won {win_count}/{count} rounds.")

                    elif u_card_val < t_card_val:  
                        b = 0 
                        print("\nYou LOST this round")
                        print("\nYou should have won every game in blackjack")  
                        fail_all()

                    
                
  
        # If user burnt, prints losing message
        if burnt == True:
            # Printing the results
            print("\nYou LOST this round")
            print("\nYou should have won every game in blackjack")  
            fail_all() 
            

# New Card function for BlackHack game
def new_card():
    # randomly picks a number between 1 - 13
    rnd = randint(1,13)  
    # For the values smaller than 11, they have the same name and value
    if rnd < 11:
        card_val = rnd
        card_name = str(card_val)  
    # For 11, it's Jack, with value 10
    elif rnd == 11:
        card_val = 10
        card_name = 'Jack'    
    # For 12, it's Queen with value 10
    elif rnd == 12:
        card_val = 10
        card_name = 'Queen'    
    # For 13, it's King with value 10
    elif rnd == 13:
        card_val = 10
        card_name = 'King'  
    # Function return the value and name of the card 
    return card_val, card_name
          
# Failing parents but he lives func, goes to main fail fnc         
def fail_parents():
    print(f"""           
Bank took {man_name}'s parent's home,
They can't even walk and they are now homeless.""")
    fail()

# Failing family and dying, goes to main fail fnc
def fail_all():
    print(f"""            
The mafia took the money and killed {man_name}.
{man_name}'s family was kicked out of their home.
and all this is because of you {user_name}""")
    fail()
    
# Dies, goes to main fail    
def dead():
    print(f"\nMafia killed {man_name}")
    fail()

# Winning prints and goes to ext function
def win():      
    print(f"""\n   
    -----------------
         YOU WON 
    -----------------""")          
    time.sleep(1)      
    print(f"\n\tYou saved {man_name}'s life and his parents.")            
    time.sleep(2)      
    print("\nDO NOT GAMBLE")             
    time.sleep(2)      
    print("\nAt least not all your money")          
    time.sleep(2)      
    print("\nHave limits for leaving the table")         
    time.sleep(2)      
    print("\nWin or lose...")
    ext()
          
# Prints fail and goes to ext func    
def fail(): 
    print("""  
            ---------------------------
                  YOU HAVE FAILED 
            ---------------------------""")
    ext()      
          
# prints ending message and ask if you want try again    
def ext():            
    print("""    
            ---------------------------
                 Thanks for playing 
            ---------------------------""")
    # Asking the question
    x = 1
    while x == 1:
        # Getting the input and making it lower case to better compare
        ans = input(prompt = ("""\n
            Do you want to try again? 

            1) Yes 
            2) No \n>- """)).lower()

        if "1" in ans or "one" in ans or "yes" in ans:
            x = 0 
            game_start()
        elif "2" in ans or "two" in ans or "tails" in ans:
            x = 0
            exit(0)
        else:
            print(f"\nSorry {user_name}, I didn't quite get that.")      
                 
# Checks if the number is a number or not and return 0 or 1          
def check_float(n):    
        try:
            # making the input into float
            number = float(n)
            return 1                
        # If not a number    
        except ValueError:
            return 0    
    
    
###############################################################################
# Game Start
###############################################################################    

game_start()
